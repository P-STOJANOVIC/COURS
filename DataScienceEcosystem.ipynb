# %% [markdown]
# # Exercise 1 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercise 2 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# => Make a screeshot with name 2-title.png

# %% [markdown]
# # Exercise 3 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# INTRODUCTION
#
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# => Make a screeshot with name 3-intro.png

# %% [markdown]
# # Exercise 10 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# INTRODUCTION
#
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives :**
# - List popular languages for Data Science
# - Some of the commonly used libraries
# - Development Environment open source used

# %% [markdown]
# => Make a screeshot with name 10-objectives.png

# %% [markdown]
# # Exercise 4 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are :
#
# 1. Python
# 2. R
# 3. SQL
# 4. SCALA
# 5. JAVA

# %% [markdown]
# => Make a screeshot with name 4-dslanguages.png

# %% [markdown]
# # Exercise 5 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include :
#
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 4. Plotly
# 5. Scikit-Learn

# %% [markdown]
# => Make a screeshot with name 5-dslibraries.png

# %% [markdown]
# # Exercise 6 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# |Data Science Tools|
# -----------------------------
# |RStudio|
# |Apache Spark|
# |TensorFlow|

# %% [markdown]
# => Make a screeshot with name 6-dstools.png

# %% [markdown]
# # Exercise 7 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# => Make a screeshot with name 7-introarithmetic.png

# %% [markdown]
# # Exercise 8 :
#
# ***
#
# ![image.png](attachment:image.png)

# %%
result = (3*4)+5
print(result)
# Out:
# 17

# %% [markdown]
# => Make a screeshot with name 8-multiplyandaddintegers.png

# %% [markdown]
# # Exercise 9 :
#
# ***
#
# ![image.png](attachment:image.png)

# %%
# This will convert 200 minutes to hours by diving by 60
result_9 = 200/60
print(result_9)
# Out:
# 3.3333333333333335

# %% [markdown]
# # Exercise 10 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# => look at the exercise 3 for the exercise 10

# %% [markdown]
# # Exercise 11 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Author :
# Stojanovic Patricija

# %% [markdown]
# => Make a screeshot with name 11-authordetails.png

# %% [markdown]
# # Exercise 12 :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# => keep the GitHub repo link of the notebook handy

# %% [markdown]
# # Exercise 13 :
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# => Make a screeshot with name 13-notebook.png
